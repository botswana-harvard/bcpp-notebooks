# %% [markdown]
# # Test your mysql Database connection

# %%
from edc_pdutils import Database
from django.conf import settings
from pprint import pprint

# %%
# confirm location of conf file
pprint(settings.DATABASES.get('default'))
# Out:
# {'ATOMIC_REQUESTS': False,
#  'AUTOCOMMIT': True,
#  'CONN_MAX_AGE': 0,
#  'ENGINE': 'django.db.backends.mysql',
#  'HOST': '',
#  'NAME': '',
#  'OPTIONS': {'read_default_file': '/Users/erikvw/source/edc-notebooks/etc/mysql.conf'},
#  'PASSWORD': '',
#  'PORT': '',
#  'TEST': {'CHARSET': None, 'COLLATION': None, 'MIRROR': None, 'NAME': None},
#  'TIME_ZONE': None,
#  'USER': ''}

# %%
# print contents of mysql.conf
mysql_conf = settings.DATABASES.get('default').get('OPTIONS').get('read_default_file')
with open(mysql_conf, 'r') as f:
    pprint([line.strip() for line in f if line.strip() and '#' not in line])
# Out:
# ['[client]',
#  'host = 127.0.0.1',
#  'port = 5004',
#  'database = edc',
#  'user = root',
#  'password = cc3721b',
#  'default-character-set = utf8']

# %%
db = Database()

# %%
db.database
# Out:
# 'edc'

# %%
db.read_sql('show databases;')
# Out:
#              Database
# 0  information_schema
# 1                 edc
# 2             hsphtmp
# 3               mysql
# 4  performance_schema
# 5                 sys
# 6               test_

# %%
db.read_sql('show tables;')
# Out:
#                                        Tables_in_edc
# 0                                         auth_group
# 1                             auth_group_permissions
# 2                                    auth_permission
# 3                                          auth_user
# 4                                   auth_user_groups
# 5                         auth_user_user_permissions
# 6                                    authtoken_token
# 7                    bcpp_clinic_subject_appointment
# 8                       bcpp_clinic_subject_dailylog
# 9                  bcpp_clinic_subject_disenrollment
# 10                    bcpp_clinic_subject_enrollment
# 11                bcpp_clinic_subject_enrollmentloss
# 12         bcpp_clinic_subject_historicalappointment
# 13            bcpp_clinic_subject_historicaldailylog
# 14       bcpp_clinic_subject_historicaldisenrollment
# 15          bcpp_clinic_subject_historicalenrollment
# 16      bcpp_clinic_subject_historicalenrollmentloss
# 17      bcpp_clinic_subject_historicalsubjectconsent
# 18  bcpp_clinic_subject_historicalsubjecteligibility
# 19      bcpp_clinic_subject_historicalsubjectlocator
# 20     bcpp_clinic_subject_historicalsubjectoffstudy
# 21        bcpp_clinic_subject_historicalsubjectvisit
# 22             bcpp_clinic_subject_identifierhistory
# 23                 bcpp_clinic_subject_questionnaire
# 24                bcpp_clinic_subject_subjectconsent
# 25            bcpp_clinic_subject_subjecteligibility
# 26                bcpp_clinic_subject_subjectlocator
# 27               bcpp_clinic_subject_subjectoffstudy
# 28            bcpp_clinic_subject_subjectrequisition
# 29                  bcpp_clinic_subject_subjectvisit
# ..                                               ...
# 52                                 edc_lab_consignee
# 53                         edc_lab_historicalaliquot
# 54                             edc_lab_historicalbox
# 55                         edc_lab_historicalboxitem
# 56                       edc_lab_historicalconsignee
# 57                        edc_lab_historicalmanifest
# 58                          edc_lab_historicalresult
# 59                      edc_lab_historicalresultitem
# 60                         edc_lab_historicalshipper
# 61                         edc_lab_identifierhistory
# 62                                  edc_lab_manifest
# 63                              edc_lab_manifestitem
# 64                                    edc_lab_result
# 65                                edc_lab_resultitem
# 66                                   edc_lab_shipper
# 67                                 edc_map_container
# 68                            edc_map_innercontainer
# 69                                  edc_map_landmark
# 70                                edc_map_mapperdata
# 71                          edc_metadata_crfmetadata
# 72                  edc_metadata_requisitionmetadata
# 73                           edc_reference_reference
# 74                edc_registration_registeredsubject
# 75                                   edc_sync_client
# 76     edc_sync_files_exportedtransactionfilehistory
# 77     edc_sync_files_importedtransactionfilehistory
# 78                                  edc_sync_history
# 79                      edc_sync_incomingtransaction
# 80                      edc_sync_outgoingtransaction
# 81                                   edc_sync_server
#
# [82 rows x 1 columns]
